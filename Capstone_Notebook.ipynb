# %% [markdown]
# # Coursera Project Capstone- The Battle of Neighborhoods

# %% [markdown]
# ### Introduction
#
# Canada is a one of the most popular destination of Indian Engineering Students for advance studies and also for doing Internships like Mitacs etc. When new students go there, they usually miss the Indian foods badly, because of unique taste of native foods.
# <p>
# This Project is aimed to help them in finding <strong>the best Indian restaurants in Toronto, the provincial capital of Ontario, Canada</strong>. </p>
#
# I chose Toronto, because, the highest concentrations of Indo-Canadians are found in the provinces of Ontario and British Columbia, followed by growing communities in Alberta and Quebec as well, with the majority of them being foreign-born.

# %% [markdown]
# ### About Data
#
#
# For the Toronto neighborhood data, a Wikipedia page: <a href = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'>wiki_page</a> exists that has all the information we need to explore and cluster the neighborhoods in Toronto. I will have to scrape the Wikipedia page and wrangle the data, clean it, and then read it into a pandas dataframe so that it is in a structured format.

# %% [markdown]
# ### Approach
#
# I will collect the Toronto city data from above <a href = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'>link</a> and using <strong>FourSquare API</strong>, I will find all venues for each neighborhood. Then, filtering out all the venues that have Indian restaurants. I will analyse ratings, tips and count for Indian restaurants. I will sort that data and visualize the ranking of neighborhoods using <strong>folium library</strong> of Python.

# %% [markdown]
# ### Problem Statement :
#
# <strong>Which is/are the best place/s to stay in the Toronto city if I prefer Indian foods ?</strong>

# %% [markdown]
# Before we get the data and start exploring it, let's download all the dependencies that we will need.

# %%
from io import StringIO

import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import requests
from bs4 import BeautifulSoup
#!pip install geocoder #uncomment if the module isn't installed
import os
#!pip install folium #uncomment if the module isn't installed
import folium # map rendering library
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
# Matplotlib and associated plotting modules
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline


print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ### Download, scrape and wrangle the data

# %%
# download data and parse it:
r = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')
soup = BeautifulSoup(r.text, 'html.parser')
# print(soup.prettify())

table=soup.find("tbody")

# make dataframe
df2 = pd.DataFrame(columns=["Postcode", "Borough", "Neighborhood"])
for tag in table.findAll("p"):
  l = [BeautifulSoup(x) for x in str(tag).split("<br/>", 2)]
  rows = []
  rows.extend(map(lambda x: str(x.text).replace('\n',"").strip("()").replace(" /",","), l))
  try:
      df2.loc[len(df2.index)] = rows
  except:
    continue

df2
# Out:
#     Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 3        M6A        North York
# 4        M7A      Queen's Park
# 5        M9A         Etobicoke
# 6        M1B       Scarborough
# 7        M3B        North York
# 8        M4B         East York
# 9        M5B  Downtown Toronto
# 10       M6B        North York
# 11       M9B         Etobicoke
# 12       M1C       Scarborough
# 13       M3C        North York
# 14       M4C         East York
# 15       M5C  Downtown Toronto
# 16       M6C              York
# 17       M9C         Etobicoke
# 18       M1E       Scarborough
# 19       M4E      East Toronto
# 20       M5E  Downtown Toronto
# 21       M6E              York
# 22       M1G       Scarborough
# 23       M4G         East York
# 24       M5G  Downtown Toronto
# 25       M6G  Downtown Toronto
# 26       M1H       Scarborough
# 27       M2H        North York
# 28       M3H        North York
# 29       M4H         East York
# 30       M5H  Downtown Toronto
# 31       M6H      West Toronto
# 32       M1J       Scarborough
# 33       M2J        North York
# 34       M3J        North York
# 35       M4J         East York
# 36       M5J  Downtown Toronto
# 37       M6J      West Toronto
# 38       M1K       Scarborough
# 39       M2K        North York
# 40       M3K        North York
# 41       M4K      East Toronto
# 42       M5K  Downtown Toronto
# 43       M6K      West Toronto
# 44       M1L       Scarborough
# 45       M2L        North York
# 46       M3L        North York
# 47       M4L      East Toronto
# 48       M5L  Downtown Toronto
# 49       M6L        North York
# 50       M9L        North York
# 51       M1M       Scarborough
# 52       M2M        North York
# 53       M3M        North York
# 54       M4M      East Toronto
# 55       M5M        North York
# 56       M6M              York
# 57       M9M        North York
# 58       M1N       Scarborough
# 59       M2N        North York
# 60       M3N        North York
# 61       M4N   Central Toronto
# 62       M5N   Central Toronto
# 63       M6N              York
# 64       M9N              York
# 65       M1P       Scarborough
# 66       M2P        North York
# 67       M4P   Central Toronto
# 68       M5P   Central Toronto
# 69       M6P      West Toronto
# 70       M9P         Etobicoke
# 71       M1R       Scarborough
# 72       M2R        North York
# 73       M4R   Central Toronto
# 74       M5R   Central Toronto
# 75       M6R      West Toronto
# 76       M7R       Mississauga
# 77       M9R         Etobicoke
# 78       M1S       Scarborough
# 79       M4S   Central Toronto
# 80       M5S  Downtown Toronto
# 81       M6S      West Toronto
# 82       M1T       Scarborough
# 83       M4T   Central Toronto
# 84       M5T  Downtown Toronto
# 85       M1V       Scarborough
# 86       M4V   Central Toronto
# 87       M5V  Downtown Toronto
# 88       M8V         Etobicoke
# 89       M9V         Etobicoke
# 90       M1W       Scarborough
# 91       M4W  Downtown Toronto
# 92       M5W  Downtown Toronto
# 93       M8W         Etobicoke
# 94       M9W         Etobicoke
# 95       M1X       Scarborough
# 96       M4X  Downtown Toronto
# 97       M5X  Downtown Toronto
# 98       M8X         Etobicoke
# 99       M4Y  Downtown Toronto
# 100      M7Y      East Toronto
# 101      M8Y         Etobicoke
# 102      M8Z         Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4                        Ontario Provincial Government
# 5                                     Islington Avenue
# 6                                       Malvern, Rouge
# 7                                      Don Mills)North
# 8                      Parkview Hill, Woodbine Gardens
# 9                             Garden District, Ryerson
# 10                                           Glencairn
# 11   West Deane Park, Princess Gardens, Martin Grov...
# 12              Rouge Hill, Port Union, Highland Creek
# 13                     Don Mills)South(Flemingdon Park
# 14                                    Woodbine Heights
# 15                                      St. James Town
# 16                                  Humewood-Cedarvale
# 17   Eringate, Bloordale Gardens, Old Burnhamthorpe...
# 18                   Guildwood, Morningside, West Hill
# 19                                         The Beaches
# 20                                         Berczy Park
# 21                                 Caledonia-Fairbanks
# 22                                              Woburn
# 23                                             Leaside
# 24                                  Central Bay Street
# 25                                            Christie
# 26                                           Cedarbrae
# 27                                   Hillcrest Village
# 28     Bathurst Manor, Wilson Heights, Downsview North
# 29                                    Thorncliffe Park
# 30                            Richmond, Adelaide, King
# 31                        Dufferin, Dovercourt Village
# 32                                 Scarborough Village
# 33                        Fairview, Henry Farm, Oriole
# 34                     Northwood Park, York University
# 35                     East Toronto(The Danforth  East
# 36   Harbourfront East, Union Station, Toronto Islands
# 37                            Little Portugal, Trinity
# 38         Kennedy Park, Ionview, East Birchmount Park
# 39                                     Bayview Village
# 40                        Downsview)East  (CFB Toronto
# 41                        The Danforth West, Riverdale
# 42            Toronto Dominion Centre, Design Exchange
# 43        Brockton, Parkdale Village, Exhibition Place
# 44                     Golden Mile, Clairlea, Oakridge
# 45                            York Mills, Silver Hills
# 46                                      Downsview)West
# 47                      India Bazaar, The Beaches West
# 48                      Commerce Court, Victoria Hotel
# 49            North Park, Maple Leaf Park, Upwood Park
# 50                                       Humber Summit
# 51     Cliffside, Cliffcrest, Scarborough Village West
# 52                             Willowdale, Newtonbrook
# 53                                   Downsview)Central
# 54                                     Studio District
# 55                   Bedford Park, Lawrence Manor East
# 56    Del Ray, Mount Dennis, Keelsdale and Silverthorn
# 57                                    Humberlea, Emery
# 58                         Birch Cliff, Cliffside West
# 59                                    Willowdale)South
# 60                                 Downsview)Northwest
# 61                                       Lawrence Park
# 62                                            Roselawn
# 63                       Runnymede, The Junction North
# 64                                              Weston
# 65   Dorset Park, Wexford Heights, Scarborough Town...
# 66                                     York Mills West
# 67                                    Davisville North
# 68                            Forest Hill North & West
# 69                       High Park, The Junction South
# 70                                           Westmount
# 71                                   Wexford, Maryvale
# 72                                     Willowdale)West
# 73                                  North Toronto West
# 74                 The Annex, North Midtown, Yorkville
# 75                              Parkdale, Roncesvalles
# 76   Canada Post Gateway Processing Centre(Enclave ...
# 77   Kingsview Village, St. Phillips, Martin Grove ...
# 78                                         Agincourt)
# 79                                          Davisville
# 80                      University of Toronto, Harbord
# 81                                  Runnymede, Swansea
# 82             Clarks Corners, Tam O'Shanter, Sullivan
# 83                         Moore Park, Summerhill East
# 84           Kensington Market, Chinatown, Grange Park
# 85   Milliken, Agincourt North, Steeles East, L'Amo...
# 86   Summerhill West, Rathnelly, South Hill, Forest...
# 87   CN Tower, King and Spadina, Railway Lands, Har...
# 88        New Toronto, Mimico South, Humber Bay Shores
# 89   South Steeles, Silverstone, Humbergate, Jamest...
# 90                       Steeles West, L'Amoreaux West
# 91                                            Rosedale
# 92       Stn A PO Boxes25 The Esplanade(Enclave of M5E
# 93                              Alderwood, Long Branch
# 94   Northwest(Clairville, Humberwood, Woodbine Dow...
# 95                                         Upper Rouge
# 96                         St. James Town, Cabbagetown
# 97              First Canadian Place, Underground city
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# 100  Business reply mail Processing Centre969 Easte...
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 102  Mimico NW, The Queensway West, South of Bloor,...

# %% [markdown]
# <strong>I will add Longitude and Latitude values for each neighborhood using <a href = 'http://cocl.us/Geospatial_data'>this data</a>.</strong>

# %%
#add Geo-spatial data
url='http://cocl.us/Geospatial_data'
s=requests.get(url).text
dfll=pd.read_csv(StringIO(s))

dfll.rename(columns={'Postal Code':'Postcode'}, inplace=True)
dfll.set_index("Postcode")
df2.set_index("Postcode")
toronto_data=pd.merge(df2, dfll)
toronto_data.head()
# Out:
#   Postcode           Borough                      Neighborhood   Latitude  \
# 0      M3A        North York                         Parkwoods  43.753259
# 1      M4A        North York                  Victoria Village  43.725882
# 2      M5A  Downtown Toronto         Regent Park, Harbourfront  43.654260
# 3      M6A        North York  Lawrence Manor, Lawrence Heights  43.718518
# 4      M7A      Queen's Park     Ontario Provincial Government  43.662301
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494

# %%
# The "Post code" column is not needed
toronto_data = toronto_data.iloc[:, 1:]
toronto_data
# Out:
#               Borough                                       Neighborhood  \
# 0          North York                                          Parkwoods
# 1          North York                                   Victoria Village
# 2    Downtown Toronto                          Regent Park, Harbourfront
# 3          North York                   Lawrence Manor, Lawrence Heights
# 4        Queen's Park                      Ontario Provincial Government
# 5           Etobicoke                                   Islington Avenue
# 6         Scarborough                                     Malvern, Rouge
# 7          North York                                    Don Mills)North
# 8           East York                    Parkview Hill, Woodbine Gardens
# 9    Downtown Toronto                           Garden District, Ryerson
# 10         North York                                          Glencairn
# 11          Etobicoke  West Deane Park, Princess Gardens, Martin Grov...
# 12        Scarborough             Rouge Hill, Port Union, Highland Creek
# 13         North York                    Don Mills)South(Flemingdon Park
# 14          East York                                   Woodbine Heights
# 15   Downtown Toronto                                     St. James Town
# 16               York                                 Humewood-Cedarvale
# 17          Etobicoke  Eringate, Bloordale Gardens, Old Burnhamthorpe...
# 18        Scarborough                  Guildwood, Morningside, West Hill
# 19       East Toronto                                        The Beaches
# 20   Downtown Toronto                                        Berczy Park
# 21               York                                Caledonia-Fairbanks
# 22        Scarborough                                             Woburn
# 23          East York                                            Leaside
# 24   Downtown Toronto                                 Central Bay Street
# 25   Downtown Toronto                                           Christie
# 26        Scarborough                                          Cedarbrae
# 27         North York                                  Hillcrest Village
# 28         North York    Bathurst Manor, Wilson Heights, Downsview North
# 29          East York                                   Thorncliffe Park
# 30   Downtown Toronto                           Richmond, Adelaide, King
# 31       West Toronto                       Dufferin, Dovercourt Village
# 32        Scarborough                                Scarborough Village
# 33         North York                       Fairview, Henry Farm, Oriole
# 34         North York                    Northwood Park, York University
# 35          East York                    East Toronto(The Danforth  East
# 36   Downtown Toronto  Harbourfront East, Union Station, Toronto Islands
# 37       West Toronto                           Little Portugal, Trinity
# 38        Scarborough        Kennedy Park, Ionview, East Birchmount Park
# 39         North York                                    Bayview Village
# 40         North York                       Downsview)East  (CFB Toronto
# 41       East Toronto                       The Danforth West, Riverdale
# 42   Downtown Toronto           Toronto Dominion Centre, Design Exchange
# 43       West Toronto       Brockton, Parkdale Village, Exhibition Place
# 44        Scarborough                    Golden Mile, Clairlea, Oakridge
# 45         North York                           York Mills, Silver Hills
# 46         North York                                     Downsview)West
# 47       East Toronto                     India Bazaar, The Beaches West
# 48   Downtown Toronto                     Commerce Court, Victoria Hotel
# 49         North York           North Park, Maple Leaf Park, Upwood Park
# 50         North York                                      Humber Summit
# 51        Scarborough    Cliffside, Cliffcrest, Scarborough Village West
# 52         North York                            Willowdale, Newtonbrook
# 53         North York                                  Downsview)Central
# 54       East Toronto                                    Studio District
# 55         North York                  Bedford Park, Lawrence Manor East
# 56               York   Del Ray, Mount Dennis, Keelsdale and Silverthorn
# 57         North York                                   Humberlea, Emery
# 58        Scarborough                        Birch Cliff, Cliffside West
# 59         North York                                   Willowdale)South
# 60         North York                                Downsview)Northwest
# 61    Central Toronto                                      Lawrence Park
# 62    Central Toronto                                           Roselawn
# 63               York                      Runnymede, The Junction North
# 64               York                                             Weston
# 65        Scarborough  Dorset Park, Wexford Heights, Scarborough Town...
# 66         North York                                    York Mills West
# 67    Central Toronto                                   Davisville North
# 68    Central Toronto                           Forest Hill North & West
# 69       West Toronto                      High Park, The Junction South
# 70          Etobicoke                                          Westmount
# 71        Scarborough                                  Wexford, Maryvale
# 72         North York                                    Willowdale)West
# 73    Central Toronto                                 North Toronto West
# 74    Central Toronto                The Annex, North Midtown, Yorkville
# 75       West Toronto                             Parkdale, Roncesvalles
# 76        Mississauga  Canada Post Gateway Processing Centre(Enclave ...
# 77          Etobicoke  Kingsview Village, St. Phillips, Martin Grove ...
# 78        Scarborough                                        Agincourt)
# 79    Central Toronto                                         Davisville
# 80   Downtown Toronto                     University of Toronto, Harbord
# 81       West Toronto                                 Runnymede, Swansea
# 82        Scarborough            Clarks Corners, Tam O'Shanter, Sullivan
# 83    Central Toronto                        Moore Park, Summerhill East
# 84   Downtown Toronto          Kensington Market, Chinatown, Grange Park
# 85        Scarborough  Milliken, Agincourt North, Steeles East, L'Amo...
# 86    Central Toronto  Summerhill West, Rathnelly, South Hill, Forest...
# 87   Downtown Toronto  CN Tower, King and Spadina, Railway Lands, Har...
# 88          Etobicoke       New Toronto, Mimico South, Humber Bay Shores
# 89          Etobicoke  South Steeles, Silverstone, Humbergate, Jamest...
# 90        Scarborough                      Steeles West, L'Amoreaux West
# 91   Downtown Toronto                                           Rosedale
# 92   Downtown Toronto      Stn A PO Boxes25 The Esplanade(Enclave of M5E
# 93          Etobicoke                             Alderwood, Long Branch
# 94          Etobicoke  Northwest(Clairville, Humberwood, Woodbine Dow...
# 95        Scarborough                                        Upper Rouge
# 96   Downtown Toronto                        St. James Town, Cabbagetown
# 97   Downtown Toronto             First Canadian Place, Underground city
# 98          Etobicoke      The Kingsway, Montgomery Road, Old Mill North
# 99   Downtown Toronto                               Church and Wellesley
# 100      East Toronto  Business reply mail Processing Centre969 Easte...
# 101         Etobicoke  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 102         Etobicoke  Mimico NW, The Queensway West, South of Bloor,...
#
#       Latitude  Longitude
# 0    43.753259 -79.329656
# 1    43.725882 -79.315572
# 2    43.654260 -79.360636
# 3    43.718518 -79.464763
# 4    43.662301 -79.389494
# 5    43.667856 -79.532242
# 6    43.806686 -79.194353
# 7    43.745906 -79.352188
# 8    43.706397 -79.309937
# 9    43.657162 -79.378937
# 10   43.709577 -79.445073
# 11   43.650943 -79.554724
# 12   43.784535 -79.160497
# 13   43.725900 -79.340923
# 14   43.695344 -79.318389
# 15   43.651494 -79.375418
# 16   43.693781 -79.428191
# 17   43.643515 -79.577201
# 18   43.763573 -79.188711
# 19   43.676357 -79.293031
# 20   43.644771 -79.373306
# 21   43.689026 -79.453512
# 22   43.770992 -79.216917
# 23   43.709060 -79.363452
# 24   43.657952 -79.387383
# 25   43.669542 -79.422564
# 26   43.773136 -79.239476
# 27   43.803762 -79.363452
# 28   43.754328 -79.442259
# 29   43.705369 -79.349372
# 30   43.650571 -79.384568
# 31   43.669005 -79.442259
# 32   43.744734 -79.239476
# 33   43.778517 -79.346556
# 34   43.767980 -79.487262
# 35   43.685347 -79.338106
# 36   43.640816 -79.381752
# 37   43.647927 -79.419750
# 38   43.727929 -79.262029
# 39   43.786947 -79.385975
# 40   43.737473 -79.464763
# 41   43.679557 -79.352188
# 42   43.647177 -79.381576
# 43   43.636847 -79.428191
# 44   43.711112 -79.284577
# 45   43.757490 -79.374714
# 46   43.739015 -79.506944
# 47   43.668999 -79.315572
# 48   43.648198 -79.379817
# 49   43.713756 -79.490074
# 50   43.756303 -79.565963
# 51   43.716316 -79.239476
# 52   43.789053 -79.408493
# 53   43.728496 -79.495697
# 54   43.659526 -79.340923
# 55   43.733283 -79.419750
# 56   43.691116 -79.476013
# 57   43.724766 -79.532242
# 58   43.692657 -79.264848
# 59   43.770120 -79.408493
# 60   43.761631 -79.520999
# 61   43.728020 -79.388790
# 62   43.711695 -79.416936
# 63   43.673185 -79.487262
# 64   43.706876 -79.518188
# 65   43.757410 -79.273304
# 66   43.752758 -79.400049
# 67   43.712751 -79.390197
# 68   43.696948 -79.411307
# 69   43.661608 -79.464763
# 70   43.696319 -79.532242
# 71   43.750071 -79.295849
# 72   43.782736 -79.442259
# 73   43.715383 -79.405678
# 74   43.672710 -79.405678
# 75   43.648960 -79.456325
# 76   43.636966 -79.615819
# 77   43.688905 -79.554724
# 78   43.794200 -79.262029
# 79   43.704324 -79.388790
# 80   43.662696 -79.400049
# 81   43.651571 -79.484450
# 82   43.781638 -79.304302
# 83   43.689574 -79.383160
# 84   43.653206 -79.400049
# 85   43.815252 -79.284577
# 86   43.686412 -79.400049
# 87   43.628947 -79.394420
# 88   43.605647 -79.501321
# 89   43.739416 -79.588437
# 90   43.799525 -79.318389
# 91   43.679563 -79.377529
# 92   43.646435 -79.374846
# 93   43.602414 -79.543484
# 94   43.706748 -79.594054
# 95   43.836125 -79.205636
# 96   43.667967 -79.367675
# 97   43.648429 -79.382280
# 98   43.653654 -79.506944
# 99   43.665860 -79.383160
# 100  43.662744 -79.321558
# 101  43.636258 -79.498509
# 102  43.628841 -79.520999

# %% [markdown]
#  ### Lets Visualize the location data :

# %%
# How many  neighborhood are there in Toronto City?
print("Total number of Neighborhood is {}".format(toronto_data.shape[0]))
# Out:
# Total number of Neighborhood is 103

# %% [markdown]
# <strong>Lets see which Borough has the most number of Neighborhood?</strong>

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of Neighborhood for each Borough in Toronto')
#On x-axis
plt.xlabel('Borough', fontsize = 15)
#On y-axis
plt.ylabel('No.of Neighborhood', fontsize=15)
#giving a bar plot
toronto_data.groupby('Borough')['Neighborhood'].count().plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %%
print("Maximum number of Neighborhoods in a single borough is {}".format(max(toronto_data.groupby('Borough')['Neighborhood'].count())))
# Out:
# Maximum number of Neighborhoods in a single borough is 24

# %% [markdown]
# ### Define Foursquare Credentials and Version
# All the below credentials are taken from <a href = 'https://foursquare.com/'>fourSquare</a>

# %%
CLIENT_ID = 'EU203ECLXW5SW1V211ZES5RUDZNHLCQ3HKADMVJHBUFZ4YLY' # your Foursquare ID
CLIENT_SECRET = 'IYS0KQOFTEKGJCJZHMKN32GMR1BNBTMS0F0RDDEMDHJNAWGA' # your Foursquare Secret
VERSION = '20200101'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: EU203ECLXW5SW1V211ZES5RUDZNHLCQ3HKADMVJHBUFZ4YLY
# CLIENT_SECRET:IYS0KQOFTEKGJCJZHMKN32GMR1BNBTMS0F0RDDEMDHJNAWGA

# %% [markdown]
# <strong> Define all the functions intract with FourSquare API and get top 50 venues within a radius of 2000 metres for a given latitude and longitude. Below function will return us the venue id , venue name and category.</strong>

# %%
def get_venues(lat,lng):
    
    #set variables
    radius=2000
    LIMIT=50
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results["response"]['groups'][0]['items']
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
        except KeyError:
            pass
        
    column_names=['ID','Name','Category']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %% [markdown]
# <strong>Function to get venue details like like count , rating , tip counts for a given venue id. This will be used for ranking.</strong>

# %%
def get_venue_details(venue_id):
        
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_rating=venue_data['rating']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
    except KeyError:
        pass
        
    column_names=['ID','Name','Likes','Rating','Tips']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %% [markdown]
# ### Let's collect the Indian Restaurants for each of the Neighbourhood

# %%
column_names=['Borough', 'Neighborhood', 'ID','Name']
indirest_toronto = pd.DataFrame(columns=column_names)
count=1
for row in toronto_data.values.tolist():
    Borough, Neighborhood, Latitude, Longitude=row
    venues = get_venues(Latitude,Longitude)
    indian_resturants = venues[venues['Category']=='Indian Restaurant']   
    print('(',count,'/',len(toronto_data),')','Indian Resturants in '+Neighborhood+', '+Borough+':'+str(len(indian_resturants)))
    for resturant_detail in indian_resturants.values.tolist():
        id, name , category = resturant_detail
        indirest_toronto = indirest_toronto.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name
                                               }, ignore_index=True)
    count+=1
# Out:
# ( 1 / 103 ) Indian Resturants in Parkwoods, North York:0
# ( 2 / 103 ) Indian Resturants in Victoria Village, North York:1
# ( 3 / 103 ) Indian Resturants in Regent Park, Harbourfront, Downtown Toronto:0
# ( 4 / 103 ) Indian Resturants in Lawrence Manor, Lawrence Heights, North York:0
# ( 5 / 103 ) Indian Resturants in Ontario Provincial Government, Queen's Park:0
# ( 6 / 103 ) Indian Resturants in Islington Avenue, Etobicoke:0
# ( 7 / 103 ) Indian Resturants in Malvern, Rouge, Scarborough:0
# ( 8 / 103 ) Indian Resturants in Don Mills)North, North York:1
# ( 9 / 103 ) Indian Resturants in Parkview Hill, Woodbine Gardens, East York:1
# ( 10 / 103 ) Indian Resturants in Garden District, Ryerson, Downtown Toronto:0
# ( 11 / 103 ) Indian Resturants in Glencairn, North York:0
# ( 12 / 103 ) Indian Resturants in West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale, Etobicoke:0
# ( 13 / 103 ) Indian Resturants in Rouge Hill, Port Union, Highland Creek, Scarborough:0
# ( 14 / 103 ) Indian Resturants in Don Mills)South(Flemingdon Park, North York:1
# ( 15 / 103 ) Indian Resturants in Woodbine Heights, East York:0
# ( 16 / 103 ) Indian Resturants in St. James Town, Downtown Toronto:0
# ( 17 / 103 ) Indian Resturants in Humewood-Cedarvale, York:1
# ( 18 / 103 ) Indian Resturants in Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood, Etobicoke:0
# ( 19 / 103 ) Indian Resturants in Guildwood, Morningside, West Hill, Scarborough:0
# ( 20 / 103 ) Indian Resturants in The Beaches, East Toronto:1
# ( 21 / 103 ) Indian Resturants in Berczy Park, Downtown Toronto:0
# ( 22 / 103 ) Indian Resturants in Caledonia-Fairbanks, York:0
# ( 23 / 103 ) Indian Resturants in Woburn, Scarborough:2
# ( 24 / 103 ) Indian Resturants in Leaside, East York:4
# ( 25 / 103 ) Indian Resturants in Central Bay Street, Downtown Toronto:0
# ( 26 / 103 ) Indian Resturants in Christie, Downtown Toronto:2
# ( 27 / 103 ) Indian Resturants in Cedarbrae, Scarborough:3
# ( 28 / 103 ) Indian Resturants in Hillcrest Village, North York:0
# ( 29 / 103 ) Indian Resturants in Bathurst Manor, Wilson Heights, Downsview North, North York:0
# ( 30 / 103 ) Indian Resturants in Thorncliffe Park, East York:2
# ( 31 / 103 ) Indian Resturants in Richmond, Adelaide, King, Downtown Toronto:0
# ( 32 / 103 ) Indian Resturants in Dufferin, Dovercourt Village, West Toronto:2
# ( 33 / 103 ) Indian Resturants in Scarborough Village, Scarborough:1
# ( 34 / 103 ) Indian Resturants in Fairview, Henry Farm, Oriole, North York:0
# ( 35 / 103 ) Indian Resturants in Northwood Park, York University, North York:0
# ( 36 / 103 ) Indian Resturants in East Toronto(The Danforth  East, East York:0
# ( 37 / 103 ) Indian Resturants in Harbourfront East, Union Station, Toronto Islands, Downtown Toronto:0
# ( 38 / 103 ) Indian Resturants in Little Portugal, Trinity, West Toronto:0
# ( 39 / 103 ) Indian Resturants in Kennedy Park, Ionview, East Birchmount Park, Scarborough:0
# ( 40 / 103 ) Indian Resturants in Bayview Village, North York:0
# ( 41 / 103 ) Indian Resturants in Downsview)East  (CFB Toronto, North York:0
# ( 42 / 103 ) Indian Resturants in The Danforth West, Riverdale, East Toronto:0
# ( 43 / 103 ) Indian Resturants in Toronto Dominion Centre, Design Exchange, Downtown Toronto:0
# ( 44 / 103 ) Indian Resturants in Brockton, Parkdale Village, Exhibition Place, West Toronto:0
# ( 45 / 103 ) Indian Resturants in Golden Mile, Clairlea, Oakridge, Scarborough:1
# ( 46 / 103 ) Indian Resturants in York Mills, Silver Hills, North York:0
# ( 47 / 103 ) Indian Resturants in Downsview)West, North York:0
# ( 48 / 103 ) Indian Resturants in India Bazaar, The Beaches West, East Toronto:2
# ( 49 / 103 ) Indian Resturants in Commerce Court, Victoria Hotel, Downtown Toronto:0
# ( 50 / 103 ) Indian Resturants in North Park, Maple Leaf Park, Upwood Park, North York:0
# ( 51 / 103 ) Indian Resturants in Humber Summit, North York:1
# ( 52 / 103 ) Indian Resturants in Cliffside, Cliffcrest, Scarborough Village West, Scarborough:0
# ( 53 / 103 ) Indian Resturants in Willowdale, Newtonbrook, North York:0
# ( 54 / 103 ) Indian Resturants in Downsview)Central, North York:0
# ( 55 / 103 ) Indian Resturants in Studio District, East Toronto:0
# ( 56 / 103 ) Indian Resturants in Bedford Park, Lawrence Manor East, North York:1
# ( 57 / 103 ) Indian Resturants in Del Ray, Mount Dennis, Keelsdale and Silverthorn, York:0
# ( 58 / 103 ) Indian Resturants in Humberlea, Emery, North York:0
# ( 59 / 103 ) Indian Resturants in Birch Cliff, Cliffside West, Scarborough:0
# ( 60 / 103 ) Indian Resturants in Willowdale)South, North York:0
# ( 61 / 103 ) Indian Resturants in Downsview)Northwest, North York:0
# ( 62 / 103 ) Indian Resturants in Lawrence Park, Central Toronto:0
# ( 63 / 103 ) Indian Resturants in Roselawn, Central Toronto:0
# ( 64 / 103 ) Indian Resturants in Runnymede, The Junction North, York:1
# ( 65 / 103 ) Indian Resturants in Weston, York:0
# ( 66 / 103 ) Indian Resturants in Dorset Park, Wexford Heights, Scarborough Town Centre, Scarborough:2
# ( 67 / 103 ) Indian Resturants in York Mills West, North York:0
# ( 68 / 103 ) Indian Resturants in Davisville North, Central Toronto:2
# ( 69 / 103 ) Indian Resturants in Forest Hill North & West, Central Toronto:0
# ( 70 / 103 ) Indian Resturants in High Park, The Junction South, West Toronto:1
# ( 71 / 103 ) Indian Resturants in Westmount, Etobicoke:0
# ( 72 / 103 ) Indian Resturants in Wexford, Maryvale, Scarborough:3
# ( 73 / 103 ) Indian Resturants in Willowdale)West, North York:1
# ( 74 / 103 ) Indian Resturants in North Toronto West, Central Toronto:0
# ( 75 / 103 ) Indian Resturants in The Annex, North Midtown, Yorkville, Central Toronto:0
# ( 76 / 103 ) Indian Resturants in Parkdale, Roncesvalles, West Toronto:0
# ( 77 / 103 ) Indian Resturants in Canada Post Gateway Processing Centre(Enclave of L4W, Mississauga:2
# ( 78 / 103 ) Indian Resturants in Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens, Etobicoke:0
# ( 79 / 103 ) Indian Resturants in Agincourt) , Scarborough:3
# ( 80 / 103 ) Indian Resturants in Davisville, Central Toronto:2
# ( 81 / 103 ) Indian Resturants in University of Toronto, Harbord, Downtown Toronto:0
# ( 82 / 103 ) Indian Resturants in Runnymede, Swansea, West Toronto:1
# ( 83 / 103 ) Indian Resturants in Clarks Corners, Tam O'Shanter, Sullivan, Scarborough:0
# ( 84 / 103 ) Indian Resturants in Moore Park, Summerhill East, Central Toronto:2
# ( 85 / 103 ) Indian Resturants in Kensington Market, Chinatown, Grange Park, Downtown Toronto:0
# ( 86 / 103 ) Indian Resturants in Milliken, Agincourt North, Steeles East, L'Amoreaux East, Scarborough:1
# ( 87 / 103 ) Indian Resturants in Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park, Central Toronto:1
# ( 88 / 103 ) Indian Resturants in CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport, Downtown Toronto:0
# ( 89 / 103 ) Indian Resturants in New Toronto, Mimico South, Humber Bay Shores, Etobicoke:3
# ( 90 / 103 ) Indian Resturants in South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens, Etobicoke:4
# ( 91 / 103 ) Indian Resturants in Steeles West, L'Amoreaux West, Scarborough:0
# ( 92 / 103 ) Indian Resturants in Rosedale, Downtown Toronto:0
# ( 93 / 103 ) Indian Resturants in Stn A PO Boxes25 The Esplanade(Enclave of M5E, Downtown Toronto:0
# ( 94 / 103 ) Indian Resturants in Alderwood, Long Branch, Etobicoke:0
# ( 95 / 103 ) Indian Resturants in Northwest(Clairville, Humberwood, Woodbine Downs, West Humber, Kipling Heights, Rexdale, Elms, Tandridge, Old Rexdale, Etobicoke:0
# ( 96 / 103 ) Indian Resturants in Upper Rouge, Scarborough:0
# ( 97 / 103 ) Indian Resturants in St. James Town, Cabbagetown, Downtown Toronto:1
# ( 98 / 103 ) Indian Resturants in First Canadian Place, Underground city, Downtown Toronto:0
# ( 99 / 103 ) Indian Resturants in The Kingsway, Montgomery Road, Old Mill North, Etobicoke:1
# ( 100 / 103 ) Indian Resturants in Church and Wellesley, Downtown Toronto:0
# ( 101 / 103 ) Indian Resturants in Business reply mail Processing Centre969 Eastern(Enclave of M4L, East Toronto:1
# ( 102 / 103 ) Indian Resturants in Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East, Etobicoke:0
# ( 103 / 103 ) Indian Resturants in Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West, Etobicoke:0

# %%
# lets see total number of indian restaurants in Toronto
print("Total number of Indian Restaurant in Toronto City is {}".format(indirest_toronto.shape[0]))
# Out:
# Total number of Indian Restaurant in Toronto City is 59

# %%
# lets print first five elements of Indian Restaurants
indirest_toronto.head()
# Out:
#       Borough                     Neighborhood                        ID  \
# 0  North York                 Victoria Village  4b9bccbef964a520ae2636e3
# 1  North York                  Don Mills)North  5bacff8d340a58002c39df9e
# 2   East York  Parkview Hill, Woodbine Gardens  4b9bccbef964a520ae2636e3
# 3  North York  Don Mills)South(Flemingdon Park  5bacff8d340a58002c39df9e
# 4        York               Humewood-Cedarvale  52418b0b7e48222eea81d2d2
#
#                 Name
# 0  Sultan Of Samosas
# 1             Mantra
# 2  Sultan Of Samosas
# 3             Mantra
# 4   Pukka Restaurant

# %% [markdown]
# ### Visualize the Indian Restaurants Data

# %% [markdown]
# <strong> <em>Which Borough has the maximum number of Indian Restaurants ? </em></strong>

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of Indian Restaurants for each Borough in Toronto City')
#On x-axis
plt.xlabel('Borough', fontsize = 15)
#On y-axis
plt.ylabel('No.of Indian Restaurants', fontsize=15)
#giving a bar plot
indirest_toronto.groupby('Borough')['ID'].count().plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %%
print("Maximum number of Indian restaurants in a single Borough is {}".format(max(indirest_toronto.groupby('Borough')['ID'].count())))
# Out:
# Maximum number of Indian restaurants in a single Borough is 16

# %% [markdown]
# <strong> <em>Which Neighborhood has the maximum number of Indian Rasoi ? </em></strong>

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of Indian Restaurants for each Neighborhood in Toronto City')
#On x-axis
plt.xlabel('Neighborhood', fontsize = 15)
#On y-axis
plt.ylabel('No. of Indian Restaurants', fontsize=15)
#giving a bar plot
indirest_toronto.groupby('Neighborhood')['ID'].count().nlargest(5).plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %%
print("Maximum number of Indian restaurants in a single Neighborhood is {}".format(max(indirest_toronto.groupby('Neighborhood')['ID'].count())))
# Out:
# Maximum number of Indian restaurants in a single Neighborhood is 4

# %% [markdown]
# ### Let's see likes, ratings and tips

# %%
# prepare neighborhood list that contains indian resturants
column_names=['Borough', 'Neighborhood', 'ID','Name','Likes','Rating','Tips']
indian_rest_stats = pd.DataFrame(columns = column_names)
count=1


for row in indirest_toronto.values.tolist():
    Borough, Neighborhood, ID, Name = row
    try:
        venue_details = get_venue_details(ID)
        print(venue_details)
        id1, name, likes, rating, tips = venue_details.values.tolist()[0]
    except IndexError:
        print('No data available for id=',ID)
        # we will assign 0 value for these resturants as they may have been 
        #recently opened or details does not exist in FourSquare Database
        id1, name, likes, rating, tips = [0]*5
    print('(',count,'/',len(indirest_toronto),')','processed')
    indian_rest_stats = indian_rest_stats.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id1,
                                                'Name' : name,
                                                'Likes' : likes,
                                                'Rating' : rating,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1
# Out:
#                          ID               Name  Likes  Rating  Tips
# 0  4b9bccbef964a520ae2636e3  Sultan Of Samosas     29     8.0    23
# ( 1 / 59 ) processed
#                          ID    Name  Likes  Rating  Tips
# 0  5bacff8d340a58002c39df9e  Mantra      5     8.2     4
# ( 2 / 59 ) processed
#                          ID               Name  Likes  Rating  Tips
# 0  4b9bccbef964a520ae2636e3  Sultan Of Samosas     29     8.0    23
# ( 3 / 59 ) processed
#                          ID    Name  Likes  Rating  Tips
# 0  5bacff8d340a58002c39df9e  Mantra      5     8.2     4
# ( 4 / 59 ) processed
#                          ID              Name  Likes  Rating  Tips
# 0  52418b0b7e48222eea81d2d2  Pukka Restaurant     41     9.0    26
# ( 5 / 59 ) processed
#                          ID                   Name  Likes  Rating  Tips
# 0  4eab2ad72c5b5d71e71cc63c  Cinamon Indian Bistro      8     7.5    11
# ( 6 / 59 ) processed
#                          ID            Name  Likes  Rating  Tips
# 0  4bd48a734e32d13a4254bf80  Govardhan Thal      7     7.3     3
# ( 7 / 59 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  4c77fc87bd346dcb8c90f0ef  La Sani Grill     11     6.7    12
# ( 8 / 59 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4b75c28af964a520ba222ee3  Kamasutra     19     8.4    12
# ( 9 / 59 ) processed
#                          ID                        Name  Likes  Rating  Tips
# 0  4daf08e66e81e2dffdd4fe40  Iqbal Kebab & Sweet Centre     12     8.0     5
# ( 10 / 59 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  5650eed9498e376aac0c2478  Indian Street Food Co.     11     7.5     4
# ( 11 / 59 ) processed
#                          ID                 Name  Likes  Rating  Tips
# 0  4c51e0069d642d7f4aef50de  Eat Indian By Amaya      7     7.2     7
# ( 12 / 59 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  4adb969ef964a520332921e3  Banjara Indian Cuisine    144     8.9    75
# ( 13 / 59 ) processed
#                          ID              Name  Likes  Rating  Tips
# 0  52418b0b7e48222eea81d2d2  Pukka Restaurant     41     9.0    26
# ( 14 / 59 ) processed
#                          ID             Name  Likes  Rating  Tips
# 0  4d6008f829ef236a8832a059  CANBE Foods Inc     23     8.3    13
# ( 15 / 59 ) processed
#                          ID            Name  Likes  Rating  Tips
# 0  4bd48a734e32d13a4254bf80  Govardhan Thal      7     7.3     3
# ( 16 / 59 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  4c77fc87bd346dcb8c90f0ef  La Sani Grill     11     6.7    12
# ( 17 / 59 ) processed
#                          ID                        Name  Likes  Rating  Tips
# 0  4daf08e66e81e2dffdd4fe40  Iqbal Kebab & Sweet Centre     12     8.0     5
# ( 18 / 59 ) processed
#                          ID              Name  Likes  Rating  Tips
# 0  507a19e5e4b0602b62f73d11  Faley Restaurant      6     6.7     4
# ( 19 / 59 ) processed
#                          ID              Name  Likes  Rating  Tips
# 0  52418b0b7e48222eea81d2d2  Pukka Restaurant     41     9.0    26
# ( 20 / 59 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  4adb969ef964a520332921e3  Banjara Indian Cuisine    144     8.9    75
# ( 21 / 59 ) processed
#                          ID                                      Name  Likes  \
# 0  4b6dbc8ef964a520fd8a2ce3  Anjappar Authentic Chettinadu Restaurant     20
#
#    Rating  Tips
# 0     7.7    10
# ( 22 / 59 ) processed
#                          ID               Name  Likes  Rating  Tips
# 0  4b9bccbef964a520ae2636e3  Sultan Of Samosas     29     8.0    23
# ( 23 / 59 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  4ae0c7a8f964a520638221e3  Udupi Palace     77     8.3    31
# ( 24 / 59 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4afc9816f964a520312422e3  Motimahal     24     7.6    13
# ( 25 / 59 ) processed
#                          ID                          Name  Likes  Rating  Tips
# 0  4b8f4165f964a5205f4f33e3  Rajdhani Sweets & Restaurant      3     6.7     6
# ( 26 / 59 ) processed
#                          ID                Name  Likes  Rating  Tips
# 0  4d796616542ab1f75eb87c41  The Copper Chimney     15     7.5    15
# ( 27 / 59 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  4b511f6ff964a520994327e3  Curry Twist     20     8.3    17
# ( 28 / 59 ) processed
#                          ID     Name  Likes  Rating  Tips
# 0  5226562611d2cd49d83ef03b  Kairali      9     7.1    10
# ( 29 / 59 ) processed
#                          ID                                         Name  \
# 0  4bf96c435317a593a23a017f  Karaikudi Chettinad South Indian Restaurant
#
#    Likes  Rating  Tips
# 0     27     6.8    22
# ( 30 / 59 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  5169d445e4b07de190b5c3d6  Marigold Indian Bistro     11     8.1    11
# ( 31 / 59 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4b75c28af964a520ba222ee3  Kamasutra     19     8.4    12
# ( 32 / 59 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  4b511f6ff964a520994327e3  Curry Twist     20     8.3    17
# ( 33 / 59 ) processed
#                          ID               Name  Likes  Rating  Tips
# 0  4c27cddd9fb5d13a8cab9857  Patna Kebab House      4     8.5     6
# ( 34 / 59 ) processed
#                          ID     Name  Likes  Rating  Tips
# 0  5226562611d2cd49d83ef03b  Kairali      9     7.1    10
# ( 35 / 59 ) processed
#                          ID                                         Name  \
# 0  4bf96c435317a593a23a017f  Karaikudi Chettinad South Indian Restaurant
#
#    Likes  Rating  Tips
# 0     27     6.8    22
# ( 36 / 59 ) processed
#                          ID                Name  Likes  Rating  Tips
# 0  51dde446498e8598c097f3d6  The Indian Cuisine      6     6.2     2
# ( 37 / 59 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  595fb4ab178a2a1a946eec2b  Barbq Tonight      7     7.0     1
# ( 38 / 59 ) processed
#                          ID  Name  Likes  Rating  Tips
# 0  4bff0c5668c7a5932a1f4044  Zauq     11     6.7    12
# ( 39 / 59 ) processed
#                          ID                                Name  Likes  \
# 0  4d570727fb65236a7f600db4  Silver Spoon Pak-Indian Restaurant     11
#
#    Rating  Tips
# 0     7.6     9
# ( 40 / 59 ) processed
#                          ID                              Name  Likes  Rating  \
# 0  4aee2557f964a52080d221e3  Samosa King - Embassy Restaurant     36     8.0
#
#    Tips
# 0    15
# ( 41 / 59 ) processed
#                          ID                                      Name  Likes  \
# 0  4b93d4a7f964a520eb5334e3  Saravanaa Bhavan South Indian Restaurant     27
#
#    Rating  Tips
# 0     8.0    12
# ( 42 / 59 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  5169d445e4b07de190b5c3d6  Marigold Indian Bistro     11     8.1    11
# ( 43 / 59 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4b75c28af964a520ba222ee3  Kamasutra     19     8.4    12
# ( 44 / 59 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  4b511f6ff964a520994327e3  Curry Twist     20     8.3    17
# ( 45 / 59 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4b75c28af964a520ba222ee3  Kamasutra     19     8.4    12
# ( 46 / 59 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  5169d445e4b07de190b5c3d6  Marigold Indian Bistro     11     8.1    11
# ( 47 / 59 ) processed
#                          ID                                      Name  Likes  \
# 0  4b93d4a7f964a520eb5334e3  Saravanaa Bhavan South Indian Restaurant     27
#
#    Rating  Tips
# 0     8.0    12
# ( 48 / 59 ) processed
#                          ID                   Name  Likes  Rating  Tips
# 0  4c62c59ce1621b8dd0332453  Roti Cuisine of India     39     8.5    20
# ( 49 / 59 ) processed
#                          ID                Name  Likes  Rating  Tips
# 0  4bc10d44abf49521d773c093  Bombay on the Lake      6     7.5     8
# ( 50 / 59 ) processed
#                          ID                          Name  Likes  Rating  Tips
# 0  5557eeff498ea920bf32ab39  Tich - Modern Indian Cuisine     11     8.4     8
# ( 51 / 59 ) processed
#                          ID                             Name  Likes  Rating  \
# 0  50a6bb8de4b0ec4c79616846  Maurya East Indian Roti Cuisine     10     6.1
#
#    Tips
# 0     6
# ( 52 / 59 ) processed
#                          ID                          Name  Likes  Rating  Tips
# 0  4b8f4165f964a5205f4f33e3  Rajdhani Sweets & Restaurant      3     6.7     6
# ( 53 / 59 ) processed
#                          ID             Name  Likes  Rating  Tips
# 0  4cead0ed9f776ea8bdcd6a22  Madras Dosa Hut      7     6.7     1
# ( 54 / 59 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  4af45ad0f964a5209bf121e3  Tandoori Time      2     6.2     5
# ( 55 / 59 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  4bca0625511f9521a6d0aec7  Brar Pakwan      4     6.2     2
# ( 56 / 59 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  4c8c21fdf0ce236ab28e15ef  Butter Chicken Factory     16     8.2    11
# ( 57 / 59 ) processed
#                          ID                          Name  Likes  Rating  Tips
# 0  4af1c64ff964a5200ae321e3  Chutneys Fine Indian Cuisine      5     6.9    10
# ( 58 / 59 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  4ae0c7a8f964a520638221e3  Udupi Palace     77     8.3    31
# ( 59 / 59 ) processed

# %%
# print first five elements of indian_rest_stats
print(indian_rest_stats.columns)
# Out:
# Index(['Borough', 'Neighborhood', 'ID', 'Name', 'Likes', 'Rating', 'Tips'], dtype='object')

# %%
# print the shape of indian_rest_stats
print(indian_rest_stats)
# Out:
#              Borough                                       Neighborhood  \
# 0         North York                                   Victoria Village
# 1         North York                                    Don Mills)North
# 2          East York                    Parkview Hill, Woodbine Gardens
# 3         North York                    Don Mills)South(Flemingdon Park
# 4               York                                 Humewood-Cedarvale
# 5       East Toronto                                        The Beaches
# 6        Scarborough                                             Woburn
# 7        Scarborough                                             Woburn
# 8          East York                                            Leaside
# 9          East York                                            Leaside
# 10         East York                                            Leaside
# 11         East York                                            Leaside
# 12  Downtown Toronto                                           Christie
# 13  Downtown Toronto                                           Christie
# 14       Scarborough                                          Cedarbrae
# 15       Scarborough                                          Cedarbrae
# 16       Scarborough                                          Cedarbrae
# 17         East York                                   Thorncliffe Park
# 18         East York                                   Thorncliffe Park
# 19      West Toronto                       Dufferin, Dovercourt Village
# 20      West Toronto                       Dufferin, Dovercourt Village
# 21       Scarborough                                Scarborough Village
# 22       Scarborough                    Golden Mile, Clairlea, Oakridge
# 23      East Toronto                     India Bazaar, The Beaches West
# 24      East Toronto                     India Bazaar, The Beaches West
# 25        North York                                      Humber Summit
# 26        North York                  Bedford Park, Lawrence Manor East
# 27              York                      Runnymede, The Junction North
# 28       Scarborough  Dorset Park, Wexford Heights, Scarborough Town...
# 29       Scarborough  Dorset Park, Wexford Heights, Scarborough Town...
# 30   Central Toronto                                   Davisville North
# 31   Central Toronto                                   Davisville North
# 32      West Toronto                      High Park, The Junction South
# 33       Scarborough                                  Wexford, Maryvale
# 34       Scarborough                                  Wexford, Maryvale
# 35       Scarborough                                  Wexford, Maryvale
# 36        North York                                    Willowdale)West
# 37       Mississauga  Canada Post Gateway Processing Centre(Enclave ...
# 38       Mississauga  Canada Post Gateway Processing Centre(Enclave ...
# 39       Scarborough                                        Agincourt)
# 40       Scarborough                                        Agincourt)
# 41       Scarborough                                        Agincourt)
# 42   Central Toronto                                         Davisville
# 43   Central Toronto                                         Davisville
# 44      West Toronto                                 Runnymede, Swansea
# 45   Central Toronto                        Moore Park, Summerhill East
# 46   Central Toronto                        Moore Park, Summerhill East
# 47       Scarborough  Milliken, Agincourt North, Steeles East, L'Amo...
# 48   Central Toronto  Summerhill West, Rathnelly, South Hill, Forest...
# 49         Etobicoke       New Toronto, Mimico South, Humber Bay Shores
# 50         Etobicoke       New Toronto, Mimico South, Humber Bay Shores
# 51         Etobicoke       New Toronto, Mimico South, Humber Bay Shores
# 52         Etobicoke  South Steeles, Silverstone, Humbergate, Jamest...
# 53         Etobicoke  South Steeles, Silverstone, Humbergate, Jamest...
# 54         Etobicoke  South Steeles, Silverstone, Humbergate, Jamest...
# 55         Etobicoke  South Steeles, Silverstone, Humbergate, Jamest...
# 56  Downtown Toronto                        St. James Town, Cabbagetown
# 57         Etobicoke      The Kingsway, Montgomery Road, Old Mill North
# 58      East Toronto  Business reply mail Processing Centre969 Easte...
#
#                           ID                                         Name  \
# 0   4b9bccbef964a520ae2636e3                            Sultan Of Samosas
# 1   5bacff8d340a58002c39df9e                                       Mantra
# 2   4b9bccbef964a520ae2636e3                            Sultan Of Samosas
# 3   5bacff8d340a58002c39df9e                                       Mantra
# 4   52418b0b7e48222eea81d2d2                             Pukka Restaurant
# 5   4eab2ad72c5b5d71e71cc63c                        Cinamon Indian Bistro
# 6   4bd48a734e32d13a4254bf80                               Govardhan Thal
# 7   4c77fc87bd346dcb8c90f0ef                                La Sani Grill
# 8   4b75c28af964a520ba222ee3                                    Kamasutra
# 9   4daf08e66e81e2dffdd4fe40                   Iqbal Kebab & Sweet Centre
# 10  5650eed9498e376aac0c2478                       Indian Street Food Co.
# 11  4c51e0069d642d7f4aef50de                          Eat Indian By Amaya
# 12  4adb969ef964a520332921e3                       Banjara Indian Cuisine
# 13  52418b0b7e48222eea81d2d2                             Pukka Restaurant
# 14  4d6008f829ef236a8832a059                              CANBE Foods Inc
# 15  4bd48a734e32d13a4254bf80                               Govardhan Thal
# 16  4c77fc87bd346dcb8c90f0ef                                La Sani Grill
# 17  4daf08e66e81e2dffdd4fe40                   Iqbal Kebab & Sweet Centre
# 18  507a19e5e4b0602b62f73d11                             Faley Restaurant
# 19  52418b0b7e48222eea81d2d2                             Pukka Restaurant
# 20  4adb969ef964a520332921e3                       Banjara Indian Cuisine
# 21  4b6dbc8ef964a520fd8a2ce3     Anjappar Authentic Chettinadu Restaurant
# 22  4b9bccbef964a520ae2636e3                            Sultan Of Samosas
# 23  4ae0c7a8f964a520638221e3                                 Udupi Palace
# 24  4afc9816f964a520312422e3                                    Motimahal
# 25  4b8f4165f964a5205f4f33e3                 Rajdhani Sweets & Restaurant
# 26  4d796616542ab1f75eb87c41                           The Copper Chimney
# 27  4b511f6ff964a520994327e3                                  Curry Twist
# 28  5226562611d2cd49d83ef03b                                      Kairali
# 29  4bf96c435317a593a23a017f  Karaikudi Chettinad South Indian Restaurant
# 30  5169d445e4b07de190b5c3d6                       Marigold Indian Bistro
# 31  4b75c28af964a520ba222ee3                                    Kamasutra
# 32  4b511f6ff964a520994327e3                                  Curry Twist
# 33  4c27cddd9fb5d13a8cab9857                            Patna Kebab House
# 34  5226562611d2cd49d83ef03b                                      Kairali
# 35  4bf96c435317a593a23a017f  Karaikudi Chettinad South Indian Restaurant
# 36  51dde446498e8598c097f3d6                           The Indian Cuisine
# 37  595fb4ab178a2a1a946eec2b                                Barbq Tonight
# 38  4bff0c5668c7a5932a1f4044                                         Zauq
# 39  4d570727fb65236a7f600db4           Silver Spoon Pak-Indian Restaurant
# 40  4aee2557f964a52080d221e3             Samosa King - Embassy Restaurant
# 41  4b93d4a7f964a520eb5334e3     Saravanaa Bhavan South Indian Restaurant
# 42  5169d445e4b07de190b5c3d6                       Marigold Indian Bistro
# 43  4b75c28af964a520ba222ee3                                    Kamasutra
# 44  4b511f6ff964a520994327e3                                  Curry Twist
# 45  4b75c28af964a520ba222ee3                                    Kamasutra
# 46  5169d445e4b07de190b5c3d6                       Marigold Indian Bistro
# 47  4b93d4a7f964a520eb5334e3     Saravanaa Bhavan South Indian Restaurant
# 48  4c62c59ce1621b8dd0332453                        Roti Cuisine of India
# 49  4bc10d44abf49521d773c093                           Bombay on the Lake
# 50  5557eeff498ea920bf32ab39                 Tich - Modern Indian Cuisine
# 51  50a6bb8de4b0ec4c79616846              Maurya East Indian Roti Cuisine
# 52  4b8f4165f964a5205f4f33e3                 Rajdhani Sweets & Restaurant
# 53  4cead0ed9f776ea8bdcd6a22                              Madras Dosa Hut
# 54  4af45ad0f964a5209bf121e3                                Tandoori Time
# 55  4bca0625511f9521a6d0aec7                                  Brar Pakwan
# 56  4c8c21fdf0ce236ab28e15ef                       Butter Chicken Factory
# 57  4af1c64ff964a5200ae321e3                 Chutneys Fine Indian Cuisine
# 58  4ae0c7a8f964a520638221e3                                 Udupi Palace
#
#    Likes  Rating Tips
# 0     29     8.0   23
# 1      5     8.2    4
# 2     29     8.0   23
# 3      5     8.2    4
# 4     41     9.0   26
# 5      8     7.5   11
# 6      7     7.3    3
# 7     11     6.7   12
# 8     19     8.4   12
# 9     12     8.0    5
# 10    11     7.5    4
# 11     7     7.2    7
# 12   144     8.9   75
# 13    41     9.0   26
# 14    23     8.3   13
# 15     7     7.3    3
# 16    11     6.7   12
# 17    12     8.0    5
# 18     6     6.7    4
# 19    41     9.0   26
# 20   144     8.9   75
# 21    20     7.7   10
# 22    29     8.0   23
# 23    77     8.3   31
# 24    24     7.6   13
# 25     3     6.7    6
# 26    15     7.5   15
# 27    20     8.3   17
# 28     9     7.1   10
# 29    27     6.8   22
# 30    11     8.1   11
# 31    19     8.4   12
# 32    20     8.3   17
# 33     4     8.5    6
# 34     9     7.1   10
# 35    27     6.8   22
# 36     6     6.2    2
# 37     7     7.0    1
# 38    11     6.7   12
# 39    11     7.6    9
# 40    36     8.0   15
# 41    27     8.0   12
# 42    11     8.1   11
# 43    19     8.4   12
# 44    20     8.3   17
# 45    19     8.4   12
# 46    11     8.1   11
# 47    27     8.0   12
# 48    39     8.5   20
# 49     6     7.5    8
# 50    11     8.4    8
# 51    10     6.1    6
# 52     3     6.7    6
# 53     7     6.7    1
# 54     2     6.2    5
# 55     4     6.2    2
# 56    16     8.2   11
# 57     5     6.9   10
# 58    77     8.3   31

# %% [markdown]
# ### Let's seet the Neighbourhood with maximum average rating of Indian Restaurant

# %%
toronto_neighborhood_stats = indian_rest_stats.groupby('Neighborhood',as_index=False).mean()[['Neighborhood','Rating']]
toronto_neighborhood_stats.columns = ['Neighborhood','Average Rating']
toronto_neighborhood_stats.sort_values(by = 'Average Rating', ascending = False, inplace = True)

toronto_neighborhood_stats.head()
# Out:
#                                          Neighborhood  Average Rating
# 15                                 Humewood-Cedarvale            9.00
# 11                       Dufferin, Dovercourt Village            8.95
# 5                                            Christie            8.95
# 27  Summerhill West, Rathnelly, South Hill, Forest...            8.50
# 2   Business reply mail Processing Centre969 Easte...            8.30

# %%
# print the neighborhood with maximum rating
print("Neighborhood : {}, Average Rating : {}".format(toronto_neighborhood_stats.iloc[0][0] ,toronto_neighborhood_stats.iloc[0][1]))
# Out:
# Neighborhood : Humewood-Cedarvale, Average Rating : 9.0

# %% [markdown]
# <strong>Lets merge this data with original data</strong>

# %%
toronto_neighborhood_stats = pd.merge(toronto_neighborhood_stats,toronto_data, on='Neighborhood')
toronto_neighborhood_stats.reset_index()
toronto_neighborhood_stats
# Out:
#                                          Neighborhood  Average Rating  \
# 0                                  Humewood-Cedarvale        9.000000
# 1                        Dufferin, Dovercourt Village        8.950000
# 2                                            Christie        8.950000
# 3   Summerhill West, Rathnelly, South Hill, Forest...        8.500000
# 4   Business reply mail Processing Centre969 Easte...        8.300000
# 5                                  Runnymede, Swansea        8.300000
# 6                       Runnymede, The Junction North        8.300000
# 7                       High Park, The Junction South        8.300000
# 8                         Moore Park, Summerhill East        8.250000
# 9                                          Davisville        8.250000
# 10                                   Davisville North        8.250000
# 11                        St. James Town, Cabbagetown        8.200000
# 12                    Don Mills)South(Flemingdon Park        8.200000
# 13                                    Don Mills)North        8.200000
# 14                    Golden Mile, Clairlea, Oakridge        8.000000
# 15                    Parkview Hill, Woodbine Gardens        8.000000
# 16                                   Victoria Village        8.000000
# 17  Milliken, Agincourt North, Steeles East, L'Amo...        8.000000
# 18                     India Bazaar, The Beaches West        7.950000
# 19                                        Agincourt)         7.866667
# 20                                            Leaside        7.775000
# 21                                Scarborough Village        7.700000
# 22                  Bedford Park, Lawrence Manor East        7.500000
# 23                                        The Beaches        7.500000
# 24                                  Wexford, Maryvale        7.466667
# 25                                          Cedarbrae        7.433333
# 26                                   Thorncliffe Park        7.350000
# 27       New Toronto, Mimico South, Humber Bay Shores        7.333333
# 28                                             Woburn        7.000000
# 29  Dorset Park, Wexford Heights, Scarborough Town...        6.950000
# 30      The Kingsway, Montgomery Road, Old Mill North        6.900000
# 31  Canada Post Gateway Processing Centre(Enclave ...        6.850000
# 32                                      Humber Summit        6.700000
# 33  South Steeles, Silverstone, Humbergate, Jamest...        6.450000
# 34                                    Willowdale)West        6.200000
#
#              Borough   Latitude  Longitude
# 0               York  43.693781 -79.428191
# 1       West Toronto  43.669005 -79.442259
# 2   Downtown Toronto  43.669542 -79.422564
# 3    Central Toronto  43.686412 -79.400049
# 4       East Toronto  43.662744 -79.321558
# 5       West Toronto  43.651571 -79.484450
# 6               York  43.673185 -79.487262
# 7       West Toronto  43.661608 -79.464763
# 8    Central Toronto  43.689574 -79.383160
# 9    Central Toronto  43.704324 -79.388790
# 10   Central Toronto  43.712751 -79.390197
# 11  Downtown Toronto  43.667967 -79.367675
# 12        North York  43.725900 -79.340923
# 13        North York  43.745906 -79.352188
# 14       Scarborough  43.711112 -79.284577
# 15         East York  43.706397 -79.309937
# 16        North York  43.725882 -79.315572
# 17       Scarborough  43.815252 -79.284577
# 18      East Toronto  43.668999 -79.315572
# 19       Scarborough  43.794200 -79.262029
# 20         East York  43.709060 -79.363452
# 21       Scarborough  43.744734 -79.239476
# 22        North York  43.733283 -79.419750
# 23      East Toronto  43.676357 -79.293031
# 24       Scarborough  43.750071 -79.295849
# 25       Scarborough  43.773136 -79.239476
# 26         East York  43.705369 -79.349372
# 27         Etobicoke  43.605647 -79.501321
# 28       Scarborough  43.770992 -79.216917
# 29       Scarborough  43.757410 -79.273304
# 30         Etobicoke  43.653654 -79.506944
# 31       Mississauga  43.636966 -79.615819
# 32        North York  43.756303 -79.565963
# 33         Etobicoke  43.739416 -79.588437
# 34        North York  43.782736 -79.442259

# %% [markdown]
# ### Let's use folium for visualization using map

# %%
toronto_map = folium.Map(location = [43.653963, -79.387207 ], zoom_start=12)
# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in toronto_neighborhood_stats[['Latitude','Longitude']].values:
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='red',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )
    
toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_da0a6a25c9a1009e1796108e2fae24a1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_da0a6a25c9a1009e1796108e2fae24a1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_da0a6a25c9a1009e1796108e2fae24a1 = L.map(
#                 &quot;map_da0a6a25c9a1009e1796108e2fae24a1&quot;,
#                 {
#                     center: [43.653963, -79.387207],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4a066ec442819924581abd7d153e9113 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_da0a6a25c9a1009e1796108e2fae24a1);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <strong>Create labels also</strong>

# %%
# create map of New York using latitude and longitude values
map_toronto = folium.Map(location = [43.653963, -79.387207 ], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(toronto_neighborhood_stats['Latitude'], toronto_neighborhood_stats['Longitude'], toronto_neighborhood_stats['Borough'], toronto_neighborhood_stats['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af31154bd8660c70e1620b0a984c51ae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af31154bd8660c70e1620b0a984c51ae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_af31154bd8660c70e1620b0a984c51ae = L.map(
#                 &quot;map_af31154bd8660c70e1620b0a984c51ae&quot;,
#                 {
#                     center: [43.653963, -79.387207],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e688492797c03938ca0aa7625b211984 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_af31154bd8660c70e1620b0a984c51ae);
#
#
#             var circle_marker_66e4b95c5110ffb5a73bbb15029f79c4 = L.circleMarker(
#                 [43.6937813, -79.4281914],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_af31154bd8660c70e1620b0a984c51ae);
#
#
#         var popup_06ca148aea1e646fb0848a6145ce0ffb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9befad21a508a059da808eadf27dcbab = $(`&lt;div id=&quot;html_9befad21a508a059da808eadf27dcbab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Humewood-Cedarvale, York&lt;/div&gt;`)[0];
#             popup_06ca148aea1e646fb0848a6145ce0ffb.setContent(html_9befad21a508a059da808eadf27dcbab);
#
#
#         circle_marker_66e4b95c5110ffb5a73bbb15029f79c4.bindPopup(popup_06ca148aea1e646fb0848a6145ce0ffb)
#         ;
#
#
#
#
#             var circle_marker_a86ca1ff9a7d75adf67f997d5f206f0d = L.circleMarker(
#                 [43.6690051, -79.4422593],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_af31154bd8660c70e1620b0a984c51ae);
#
#
#         var popup_a4adb4ac8e7c1179c5d8135c879ae26c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e8f54cee58edec61ee16ac3c84d24d5b = $(`&lt;div id=&quot;html_e8f54cee58edec61ee16ac3c84d24d5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dufferin, Dovercourt Village, West Toronto&lt;/div&gt;`)[0];
#             popup_a4adb4ac8e7c1179c5d8135c879ae26c.setContent(html_e8f54cee58edec61ee16ac3c84d24d5b);
#
#
#         circle_marker_a86ca1ff9a7d75adf67f997d5f206f0d.bindPopup(popup_a4adb4ac8e7c1179c5d8135c879ae26c)
#         ;
#
#
#
#
#             var circle_marker_d59774e7f1e8f4254850f0494c85c8a0 = L.circleMarker(
#                 [43.669542, -79.4225637],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_af31154bd8660c70e1620b0a984c51ae);
#
#
#         var popup_09f212a92c5d3ca85b16f4b9df6021cc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_327d841d965bd5c18046b303505b4540 = $(`&lt;div id=&quot;html_327d841d965bd5c18046b303505b4540&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Christie, Downtown Toronto&lt;/div&gt;`)[0];
#             popup_09f212a92c5d3ca85b16f4b9df6021cc.setContent(html_327d841d965bd5c18046b303505b4540);
#
#
#         circle_marker_d59774e7f1e8f4254850f0494c85c8a0.bindPopup(popup_09f212a92c5d3ca85b16f4b9df6021cc)
#         ;
#
#
#
#
#             var circle_marker_199e02cecd06249350df6956f0ff4727 = L.circleMarker(
#                 [43.6864123, -79.4000493],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;line

# %% [markdown]
# ##### Save the map

# %%
map_toronto.save('Neighbourhood_rating.html')

# %% [markdown]
# ## Conclusion

# %% [markdown]
# <ul>
#     <li>Humewood-Cedarvale,Dufferin, Dovercourt Village	are some of the best neighborhoods for Indian Restaurants. </li>
#     <li>York (borough) is the best place if you prefer Indian foods.</li>
# </ul>

# %% [markdown]
# ## Limitations

# %% [markdown]
# <ul><li>The accuracy is dependent on the data provided by FourSquare and the ranking is dependent on the user ratings.</li></ul>
